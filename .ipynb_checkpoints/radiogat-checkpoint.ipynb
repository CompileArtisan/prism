# %%
# !git clone https://github.com/Lxj321/RadioGAT-Multi-band-Radiomap-Reconstruction.git

# %%
# %cd RadioGAT-Multi-band-Radiomap-Reconstruction
# Out:
# /home/praaneshnair/random/prism/RadioGAT-Multi-band-Radiomap-Reconstruction

# %%
import sys
# !uv pip install --python {sys.executable} torch torch-geometric scipy numpy matplotlib scikit-learn
# !uv pip install --python {sys.executable} numba -q
# Out:
# Using Python 3.12.12 environment at: /home/praaneshnair/OneDrive/Assignments/Semester-7/reinforcement-learning/.venv
# Audited 6 packages in 5ms

# %%
import os, math
import numpy as np
import scipy.io as scio
import torch
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error
from tqdm.auto import tqdm

NumFreq   = 5
Freq      = [1750, 2750, 3750, 4750, 5750]
NumArea   = 10
Blockx = Blocky = 40

# Flip to True to sanity-check the whole pipeline on 1 area / a couple of blocks / 3 epochs
# before committing to the full (many-hour) run.
QUICK_TEST = False
QUICK_TEST_BLOCKS = 2   # must match the "n_blocks" used in Cell 5's quick-test branch

# %%
for i in tqdm(range(NumArea), desc="Data_read: areas"):
    os.makedirs(f'Strength/{i+1}', exist_ok=True)
    os.makedirs(f'NewStrength{Blockx}/{i+1}', exist_ok=True)
    for j in tqdm(range(NumFreq), desc=f"  area {i+1} freqs", leave=False):
        FileName = f'receivedpower_{Freq[j]}MHz_mat/TOTAL_REC_{Freq[j]}MHz_{i+1}.mat'
        Data = scio.loadmat(FileName)
        NewData = np.array(Data[f'powers{j+1}'])
        np.savetxt(f'Strength/{i+1}/{Freq[j]}.txt', NewData, fmt='%.4f')
        ProcessdData = NewData[0:Blocky*int(NewData.shape[0]/Blocky),
                                0:Blockx*int(NewData.shape[1]/Blockx)]
        np.savetxt(f'NewStrength{Blockx}/{i+1}/{Freq[j]}.txt', ProcessdData, fmt='%.4f')

for i in tqdm(range(NumArea), desc="Data_read: splitting"):
    for j in range(NumFreq):
        os.makedirs(f'SplitStrength{Blockx}/{i+1}/{Freq[j]}', exist_ok=True)
        All_Area = np.loadtxt(f'NewStrength{Blockx}/{i+1}/{Freq[j]}.txt', dtype=float)
        for m in range(int(All_Area.shape[0]/Blocky)):
            for n in range(int(All_Area.shape[1]/Blockx)):
                np.savetxt(f'SplitStrength{Blockx}/{i+1}/{Freq[j]}/{m+1}_{n+1}.txt',
                           All_Area[m*Blocky:(m+1)*Blocky, n*Blockx:(n+1)*Blockx], fmt='%.4f')
# Out:
# Data_read: areas:   0%|          | 0/10 [00:00<?, ?it/s]
#   area 1 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 2 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 3 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 4 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 5 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 6 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 7 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 8 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 9 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 10 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
# Data_read: splitting:   0%|          | 0/10 [00:00<?, ?it/s]

# %%
kaolvjuli = 0
sigma = 0.1
StationsPosition = np.loadtxt('stations_position.txt', dtype=int)
os.makedirs(f'TopologyDepth{sigma}', exist_ok=True)

areas = range(1) if QUICK_TEST else range(NumArea)

for AreaIndex in tqdm(areas, desc="Radio_Depth: areas"):
    os.makedirs(f'LossProb/{AreaIndex+1}', exist_ok=True)
    Sampling_Strength = np.loadtxt(f'NewStrength{Blockx}/{AreaIndex+1}/{Freq[0]}.txt')

    All_Topology = Sampling_Strength
    All_Topology[np.where(All_Topology != 0)] = -1
    All_Topology[np.where(All_Topology == 0)] = 1
    All_Topology[np.where(All_Topology == -1)] = 0

    Num_tri = 3
    Axis_tr = np.ones((2, 3), dtype=int)
    Axis_tr[:, 0] = np.array(StationsPosition[AreaIndex, 0:2]) - 1
    Axis_tr[:, 1] = np.array(StationsPosition[AreaIndex, 2:4]) - 1
    Axis_tr[:, 2] = np.array(StationsPosition[AreaIndex, 4:6]) - 1

    stride0 = 1
    pool = nn.AvgPool2d(stride0, stride=stride0)
    zhongjian = torch.tensor(np.ones((1, All_Topology.shape[0], All_Topology.shape[1])))
    zhongjian[0, :, :] = torch.tensor(All_Topology)
    Avg_All_Topology = pool(torch.tensor(zhongjian))[0].numpy()

    Avg_Axis_tr = np.ones((2, 3), dtype=int)
    Avg_Axis_tr[:, 0] = Axis_tr[:, 0] / stride0
    Avg_Axis_tr[:, 1] = Axis_tr[:, 1] / stride0
    Avg_Axis_tr[:, 2] = Axis_tr[:, 2] / stride0

    Para_Avg_All_Topology = np.ones((3, 3, Avg_All_Topology.shape[0], Avg_All_Topology.shape[1]))
    Para_Avg_All_Topology[:, 2, :, :] = 0

    for i in tqdm(range(Num_tri), desc=f"  area {AreaIndex+1} transmitters", leave=False):
        Para_Avg_All_Topology[i, 1, np.where(Para_Avg_All_Topology[i, 1, :, :] >= 0)[0],
                                     np.where(Para_Avg_All_Topology[i, 1, :, :] >= 0)[1]] = np.sqrt(
            (np.where(Para_Avg_All_Topology[i, 1, :, :] >= 0)[0] - Avg_Axis_tr[0, i]) ** 2 +
            (np.where(Para_Avg_All_Topology[i, 1, :, :] >= 0)[1] - Avg_Axis_tr[1, i]) ** 2)

        for k in tqdm(range(Avg_All_Topology.shape[1]), desc=f"    tx {i+1} columns", leave=False):
            for j in range(Avg_All_Topology.shape[0]):
                if k < Avg_Axis_tr[1, i]:
                    X_Index = np.array(range(k, Avg_Axis_tr[1, i], 1))
                    Y_Index = np.array((Avg_Axis_tr[0, i]-j)/(Avg_Axis_tr[1, i]-k)*(X_Index-k)+j).astype(int)
                    Para_Avg_All_Topology[i, 0, j, k] = np.sum(Avg_All_Topology[Y_Index, X_Index]) / np.shape(X_Index)[0]
                elif k > Avg_Axis_tr[1, i]:
                    X_Index = np.array(range(k, Avg_Axis_tr[1, i], -1))
                    Y_Index = np.array((Avg_Axis_tr[0, i]-j)/(Avg_Axis_tr[1, i]-k)*(X_Index-k)+j).astype(int)
                    Para_Avg_All_Topology[i, 0, j, k] = np.sum(Avg_All_Topology[Y_Index, X_Index]) / np.shape(X_Index)[0]
                else:
                    X_Index = Avg_Axis_tr[1, i]
                    if j < Avg_Axis_tr[0, i]:
                        Y_Index = np.array(range(j, Avg_Axis_tr[0, i], 1))
                        # FIX: original code divided by np.shape(Y_Index) (a tuple) instead of
                        # np.shape(Y_Index)[0] (the int count) -- crashes with
                        # "setting an array element with a sequence" the first time this branch fires.
                        Para_Avg_All_Topology[i, 0, j, k] = np.sum(Avg_All_Topology[Y_Index, X_Index]) / np.shape(Y_Index)[0]
                    elif j > Avg_Axis_tr[0, i]:
                        Y_Index = np.array(range(j, Avg_Axis_tr[0, i], -1))
                        # FIX: same missing [0] here.
                        Para_Avg_All_Topology[i, 0, j, k] = np.sum(Avg_All_Topology[Y_Index, X_Index]) / np.shape(Y_Index)[0]
                    else:
                        Y_Index = Avg_Axis_tr[0, i]
                        Para_Avg_All_Topology[i, 0, j, k] = np.sum(Avg_All_Topology[Y_Index, X_Index])

    if kaolvjuli == 1:
        for i in range(Num_tri):
            Para_Avg_All_Topology[i, 2, :, :] = (1 - Para_Avg_All_Topology[i, 0, :, :]) / (Para_Avg_All_Topology[i, 1, :, :] ** sigma)
        DepthMap = Para_Avg_All_Topology[0, 2, :, :] + Para_Avg_All_Topology[1, 2, :, :] + Para_Avg_All_Topology[2, 2, :, :]
        np.savetxt(f'TopologyDepth{sigma}/{AreaIndex+1}.txt', DepthMap, fmt='%f')
    else:
        for i in range(Num_tri):
            Para_Avg_All_Topology[i, 2, :, :] = 1 - Para_Avg_All_Topology[i, 0, :, :]
            np.savetxt(f'LossProb/{AreaIndex+1}/{i+1}.txt', Para_Avg_All_Topology[i, 2, :, :], fmt='%f')
# Out:
# Radio_Depth: areas:   0%|          | 0/10 [00:00<?, ?it/s]
# /tmp/ipykernel_44378/343280727.py:27: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   Avg_All_Topology = pool(torch.tensor(zhongjian))[0].numpy()
#   area 1 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/480 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/480 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/480 [00:00<?, ?it/s]
#   area 2 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/560 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/560 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/560 [00:00<?, ?it/s]
#   area 3 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/520 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/520 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/520 [00:00<?, ?it/s]
#   area 4 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/440 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/440 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/440 [00:00<?, ?it/s]
#   area 5 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/560 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/560 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/560 [00:00<?, ?it/s]
#   area 6 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/480 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/480 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/480 [00:00<?, ?it/s]
#   area 7 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/520 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/520 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/520 [00:00<?, ?it/s]
#   area 8 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/560 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/560 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/560 [00:00<?, ?it/s]
#   area 9 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/480 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/480 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/480 [00:00<?, ?it/s]
#   area 10 transmitters:   0%|          | 0/3 [00:00<?, ?it/s]
#     tx 1 columns:   0%|          | 0/400 [00:00<?, ?it/s]
#     tx 2 columns:   0%|          | 0/400 [00:00<?, ?it/s]
#     tx 3 columns:   0%|          | 0/400 [00:00<?, ?it/s]

# %%
for i in tqdm(range(NumArea), desc="NodeFeature: areas"):
    for j in tqdm(range(NumFreq), desc=f"  area {i+1} freqs", leave=False):
        os.makedirs(f'NodeFeatureAxis{Blockx}/{i+1}/{Freq[j]}', exist_ok=True)
        os.makedirs(f'NodeFeatureStrength{Blockx}/{i+1}/{Freq[j]}', exist_ok=True)
        All_Area = np.loadtxt(f'NewStrength{Blockx}/{i+1}/{Freq[j]}.txt', dtype=float)
        for m in range(int(All_Area.shape[0]/Blocky)):
            for n in range(int(All_Area.shape[1]/Blockx)):
                Data = np.loadtxt(f'SplitStrength{Blockx}/{i+1}/{Freq[j]}/{m+1}_{n+1}.txt', dtype=float)
                np.savetxt(f'NodeFeatureAxis{Blockx}/{i+1}/{Freq[j]}/{m+1}_{n+1}.txt', np.where(Data != 0), fmt='%d')
                np.savetxt(f'NodeFeatureStrength{Blockx}/{i+1}/{Freq[j]}/{m+1}_{n+1}.txt', Data[np.where(Data != 0)], fmt='%.4f')
# Out:
# NodeFeature: areas:   0%|          | 0/10 [00:00<?, ?it/s]
#   area 1 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 2 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 3 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 4 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 5 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 6 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 7 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 8 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 9 freqs:   0%|          | 0/5 [00:00<?, ?it/s]
#   area 10 freqs:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
BlockX = BlockY = 40
sita = 0.1
dcor = 4.5
Num_Axis = 3
sigma1 = 0.5
chayufenzi = 0.1
Carry_Freq = np.array(Freq)
Frequency = np.array(Freq)
Num_Node_MAX = 1600
Adj = np.ones((Num_Node_MAX, Num_Node_MAX), dtype=int)
axis = np.loadtxt(f'New_axis{BlockX}.txt', dtype=int)

def compute_adj_original_loop(suoyin, SFDepth, chayuzhi, dcor, Num_Node_MAX):
    """Unmodified brute-force reference implementation, for verification only."""
    A = np.zeros((Num_Node_MAX, Num_Node_MAX), dtype=int)
    for mo in range(suoyin.shape[1]):
        for no in range(suoyin.shape[1]):
            if np.sqrt((suoyin[0,mo]-suoyin[0,no])**2 + (suoyin[1,mo]-suoyin[1,no])**2) < dcor:
                if (abs(SFDepth[0,suoyin[0,mo],suoyin[1,mo]]) - abs(SFDepth[0,suoyin[0,no],suoyin[1,no]]) <= chayuzhi and
                    abs(SFDepth[1,suoyin[0,mo],suoyin[1,mo]]) - abs(SFDepth[1,suoyin[0,no],suoyin[1,no]]) <= chayuzhi and
                    abs(SFDepth[2,suoyin[0,mo],suoyin[1,mo]]) - abs(SFDepth[2,suoyin[0,no],suoyin[1,no]]) <= chayuzhi):
                    A[mo, no] = 1
    return A[0:suoyin.shape[1], 0:suoyin.shape[1]]

def compute_adj_vectorized(suoyin, SFDepth, chayuzhi, dcor):
    """Vectorized replacement -- same condition, same subtraction order (not symmetric,
    so order matters and is preserved exactly)."""
    y_coords, x_coords = suoyin[0, :], suoyin[1, :]
    absSF = np.abs(SFDepth[:, y_coords, x_coords])  # (3, N)
    dx = x_coords[:, None] - x_coords[None, :]
    dy = y_coords[:, None] - y_coords[None, :]
    dist_mask = np.sqrt(dx.astype(float)**2 + dy.astype(float)**2) < dcor
    diff0 = absSF[0][:, None] - absSF[0][None, :]
    diff1 = absSF[1][:, None] - absSF[1][None, :]
    diff2 = absSF[2][:, None] - absSF[2][None, :]
    cond = dist_mask & (diff0 <= chayuzhi) & (diff1 <= chayuzhi) & (diff2 <= chayuzhi)
    return cond.astype(int)

# %%
# --- SELF-CHECK: run this before trusting the vectorized version below ---
# Compares old vs new logic on one real block. Should print "MATCH".
_AreaIndex = 0
_m, _n = 0, 0
_Spatial_Depth_Map1 = np.loadtxt(f'LossProb/{_AreaIndex+1}/1.txt', dtype=float)
_Spatial_Depth_Map2 = np.loadtxt(f'LossProb/{_AreaIndex+1}/2.txt', dtype=float)
_Spatial_Depth_Map3 = np.loadtxt(f'LossProb/{_AreaIndex+1}/3.txt', dtype=float)
_SFDepth = np.stack([_Spatial_Depth_Map1, _Spatial_Depth_Map2, _Spatial_Depth_Map3])
_suoyin = np.loadtxt(f'NodeFeatureAxis{BlockX}/{_AreaIndex+1}/{Carry_Freq[0]}/{_m+1}_{_n+1}.txt', dtype=int)
_chayuzhi = chayufenzi / math.log(Frequency[0], 10)

_ref = compute_adj_original_loop(_suoyin, _SFDepth, _chayuzhi, dcor, Num_Node_MAX)
_fast = compute_adj_vectorized(_suoyin, _SFDepth, _chayuzhi, dcor)
assert np.array_equal(_ref, _fast), "MISMATCH -- do not trust the vectorized version, fall back to the loop"
print("MATCH -- vectorized version verified equivalent on this block")
# Out:
# MATCH -- vectorized version verified equivalent on this block

# %%
# --- Full run ---
areas = range(1) if QUICK_TEST else range(NumArea)

for AreaIndex in tqdm(areas, desc="Depth_Adj: areas"):
    Spatial_Depth_Map1 = np.loadtxt(f'LossProb/{AreaIndex+1}/1.txt', dtype=float)
    Spatial_Depth_Map2 = np.loadtxt(f'LossProb/{AreaIndex+1}/2.txt', dtype=float)
    Spatial_Depth_Map3 = np.loadtxt(f'LossProb/{AreaIndex+1}/3.txt', dtype=float)
    SFDepth = np.stack([Spatial_Depth_Map1, Spatial_Depth_Map2, Spatial_Depth_Map3])

    Num_All_Block   = int(axis[AreaIndex,0]*axis[AreaIndex,1]/BlockY/BlockX)
    Num_All_Block_X = int(axis[AreaIndex,1]/BlockX)


    n_blocks = QUICK_TEST_BLOCKS if QUICK_TEST else Num_All_Block

    for BlockIndex in tqdm(range(n_blocks), desc=f"  area {AreaIndex+1} blocks", leave=False):
        m = int(BlockIndex/Num_All_Block_X)
        n = int(BlockIndex - m*Num_All_Block_X)
        suoyin = np.loadtxt(f'NodeFeatureAxis{BlockX}/{AreaIndex+1}/{Carry_Freq[0]}/{m+1}_{n+1}.txt', dtype=int)
        Num_Node = suoyin.shape[1]

        for j in range(NumFreq):
            os.makedirs(f'FreqDepth{chayufenzi}/{AreaIndex+1}/{Frequency[j]}', exist_ok=True)
            chayuzhi = chayufenzi / math.log(Frequency[j], 10)
            adj = compute_adj_vectorized(suoyin, SFDepth, chayuzhi, dcor)
            np.savetxt(f'FreqDepth{chayufenzi}/{AreaIndex+1}/{Frequency[j]}/{m+1}_{n+1}.txt', adj, fmt='%d')

        tqdm.write(f"area {AreaIndex+1} block {BlockIndex+1}/{n_blocks} ({Num_Node} nodes) done")
# Out:
# Depth_Adj: areas:   0%|          | 0/10 [00:00<?, ?it/s]
#   area 1 blocks:   0%|          | 0/132 [00:00<?, ?it/s]
# area 1 block 1/132 (1560 nodes) done
# area 1 block 2/132 (1510 nodes) done
# area 1 block 3/132 (1482 nodes) done
# area 1 block 4/132 (1515 nodes) done
# area 1 block 5/132 (1498 nodes) done
# area 1 block 6/132 (1528 nodes) done
# area 1 block 7/132 (1503 nodes) done
# area 1 block 8/132 (1406 nodes) done
# area 1 block 9/132 (1276 nodes) done
# area 1 block 10/132 (1499 nodes) done
# area 1 block 11/132 (1479 nodes) done
# area 1 block 12/132 (1438 nodes) done
# area 1 block 13/132 (1542 nodes) done
# area 1 block 14/132 (1422 nodes) done
# area 1 block 15/132 (1568 nodes) done
# area 1 block 16/132 (1452 nodes) done
# area 1 block 17/132 (1548 nodes) done
# area 1 block 18/132 (1566 nodes) done
# area 1 block 19/132 (1595 nodes) done
# area 1 block 20/132 (1596 nodes) done
# area 1 block 21/132 (1403 nodes) done
# area 1 block 22/132 (1588 nodes) done
# area 1 block 23/132 (1508 nodes) done
# area 1 block 24/132 (1442 nodes) done
# area 1 block 25/132 (1524 nodes) done
# area 1 block 26/132 (1563 nodes) done
# area 1 block 27/132 (1588 nodes) done
# area 1 block 28/132 (1556 nodes) done
# area 1 block 29/132 (1599 nodes) done
# area 1 block 30/132 (1532 nodes) done
# area 1 block 31/132 (1582 nodes) done
# area 1 block 32/132 (1553 nodes) done
# area 1 block 33/132 (1421 nodes) done
# area 1 block 34/132 (1406 nodes) done
# area 1 block 35/132 (1397 nodes) done
# area 1 block 36/132 (1436 nodes) done
# area 1 block 37/132 (1504 nodes) done
# area 1 block 38/132 (1557 nodes) done
# area 1 block 39/132 (1592 nodes) done
# area 1 block 40/132 (1541 nodes) done
# area 1 block 41/132 (1510 nodes) done
# area 1 block 42/132 (1555 nodes) done
# area 1 block 43/132 (1582 nodes) done
# area 1 block 44/132 (1581 nodes) done
# area 1 block 45/132 (1316 nodes) done
# area 1 block 46/132 (1413 nodes) done
# area 1 block 47/132 (1498 nodes) done
# area 1 block 48/132 (1519 nodes) done
# area 1 block 49/132 (1365 nodes) done
# area 1 block 50/132 (1441 nodes) done
# area 1 block 51/132 (1499 nodes) done
# area 1 block 52/132 (1502 nodes) done
# area 1 block 53/132 (1582 nodes) done
# area 1 block 54/132 (1527 nodes) done
# area 1 block 55/132 (1600 nodes) done
# area 1 block 56/132 (1564 nodes) done
# area 1 block 57/132 (1378 nodes) done
# area 1 block 58/132 (1414 nodes) done
# area 1 block 59/132 (1336 nodes) done
# area 1 block 60/132 (1367 nodes) done
# area 1 block 61/132 (1360 nodes) done
# area 1 block 62/132 (1343 nodes) done
# area 1 block 63/132 (1212 nodes) done
# area 1 block 64/132 (1176 nodes) done
# area 1 block 65/132 (1505 nodes) done
# area 1 block 66/132 (1545 nodes) done
# area 1 block 67/132 (1516 nodes) done
# area 1 block 68/132 (1464 nodes) done
# area 1 block 69/132 (1339 nodes) done
# area 1 block 70/132 (1356 nodes) done
# area 1 block 71/132 (1359 nodes) done
# area 1 block 72/132 (1307 nodes) done
# area 1 block 73/132 (1363 nodes) done
# area 1 block 74/132 (1234 nodes) done
# area 1 block 75/132 (1325 nodes) done
# area 1 block 76/132 (1486 nodes) done
# area 1 block 77/132 (1289 nodes) done
# area 1 block 78/132 (1307 nodes) done
# area 1 block 79/132 (1545 nodes) done
# area 1 block 80/132 (1542 nodes) done
# area 1 block 81/132 (1453 nodes) done
# area 1 block 82/132 (1377 nodes) done
# area 1 block 83/132 (1253 nodes) done
# area 1 block 84/132 (1261 nodes) done
# area 1 block 85/132 (1414 nodes) done
# area 1 block 86/132 (1266 nodes) done
# area 1 block 87/132 (1335 nodes) done
# area 1 block 88/132 (1365 nodes) done
# area 1 block 89/132 (1348 nodes) done
# area 1 block 90/132 (1177 nodes) done
# area 1 block 91/132 (1404 nodes) done
# area 1 block 92/132 (1229 nodes) done
# area 1 block 93/132 (1314 nodes) done
# area 1 block 94/132 (1195 nodes) done
# area 1 block 95/132 (1223 nodes) done
# area 1 block 96/132 (1004 nodes) done
# area 1 block 97/132 (1600 nodes) done
# area 1 block 98/132 (1382 nodes) done
# area 1 block 99/132 (1332 nodes) done
# area 1 block 100/132 (1029 nodes) done
# area 1 block 101/132 (1580 nodes) done
# area 1 block 102/132 (1304 nodes) done
# area 1 block 103/132 (1207 nodes) done
# area 1 block 104/132 (1155 nodes) done
# area 1 block 105/132 (1442 nodes) done
# area 1 block 106/132 (1232 nodes) done
# area 1 block 107/132 (1152 nodes) done
# area 1 block 108/132 (1085 nodes) done
# area 1 block 109/132 (1600 nodes) done
# area 1 block 110/132 (1529 nodes) done
# area 1 block 111/132 (1357 nodes) done
# area 1 block 112/132 (1477 nodes) done
# area 1 block 113/132 (1241 nodes) done
# area 1 block 114/132 (1159 nodes) done
# area 1 block 115/132 (1028 nodes) done
# area 1 block 116/132 (1387 nodes) done
# area 1 block 117/132 (1403 nodes) done
# area 1 block 118/132 (1464 nodes) done
# area 1 block 119/132 (1363 nodes) done
# area 1 block 120/132 (1473 nodes) done
# area 1 block 121/132 (1534 nodes) done
# area 1 block 122/132 (1245 nodes) done
# area 1 block 123/132 (1584 nodes) done
# area 1 block 124/132 (1558 nodes) done
# area 1 block 125/132 (1348 nodes) done
# area 1 block 126/132 (1073 nodes) done
# area 1 block 127/132 (1343 nodes) done
# area 1 block 128/132 (1432 nodes) done
# area 1 block 129/132 (1308 nodes) done
# area 1 block 130/132 (1542 nodes) done
# area 1 block 131/132 (1323 nodes) done
# area 1 block 132/132 (1576 nodes) done
#   area 2 blocks:   0%|          | 0/140 [00:00<?, ?it/s]
# area 2 block 1/140 (1426 nodes) done
# area 2 block 2/140 (1400 nodes) done
# area 2 block 3/140 (1471 nodes) done
# area 2 block 4/140 (1499 nodes) done
# area 2 block 5/140 (1526 nodes) done
# area 2 block 6/140 (1538 nodes) done
# area 2 block 7/140 (1505 nodes) done
# area 2 block 8/140 (1499 nodes) done
# area 2 block 9/140 (1507 nodes) done
# area 2 block 10/140 (1523 nodes) done
# area 2 block 11/140 (1527 nodes) done
# area 2 block 12/140 (1529 nodes) done
# area 2 block 13/140 (1528 nodes) done
# area 2 block 14/140 (1488 nodes) done
# area 2 block 15/140 (1513 nodes) done
# area 2 block 16/140 (1564 nodes) done
# area 2 block 17/140 (1545 nodes) done
# area 2 block 18/140 (1513 nodes) done
# area 2 block 19/140 (1521 nodes) done
# area 2 block 20/140 (1551 nodes) done
# area 2 block 21/140 (1564 nodes) done
# area 2 block 22/140 (1488 nodes) done
# area 2 block 23/140 (1501 nodes) done
# area 2 block 24/140 (1580 nodes) done
# area 2 block 25/140 (1555 nodes) done
# area 2 block 26/140 (1563 nodes) done
# area 2 block 27/140 (1570 nodes) done
# area 2 block 28/140 (1517 nodes) done
# area 2 block 29/140 (1599 nodes) done
# area 2 block 30/140 (1553 nodes) done
# area 2 block 31/140 (1514 nodes) done
# area 2 block 32/140 (1560 nodes) done
# area 2 block 33/140 (1515 nodes) done
# area 2 block 34/140 (1561 nodes) done
# area 2 block 35/140 (1565 nodes) done
# area 2 block 36/140 (1547 nodes) done
# area 2 block 37/140 (1534 nodes) done
# area 2 block 38/140 (1572 nodes) done
# area 2 block 39/140 (1536 nodes) done
# area 2 block 40/140 (1550 nodes) done
# area 2 block 41/140 (1567 nodes) done
# area 2 block 42/140 (1551 nodes) done
# area 2 block 43/140 (1600 nodes) done
# area 2 block 44/140 (1527 nodes) done
# area 2 block 45/140 (1532 nodes) done
# area 2 block 46/140 (1507 nodes) done
# area 2 block 47/140 (1521 nodes) done
# area 2 block 48/140 (1512 nodes) done
# area 2 block 49/140 (1573 nodes) done
# area 2 block 50/140 (1560 nodes) done
# area 2 block 51/140 (1545 nodes) done
# area 2 block 52/140 (1578 nodes) done
# area 2 block 53/140 (1551 nodes) done
# area 2 block 54/140 (1545 nodes) done
# area 2 block 55/140 (1579 nodes) done
# area 2 block 56/140 (1549 nodes) done
# area 2 block 57/140 (1600 nodes) done
# area 2 block 58/140 (1600 nodes) done
# area 2 block 59/140 (1548 nodes) done
# area 2 block 60/140 (1526 nodes) done
# area 2 block 61/140 (1562 nodes) done
# area 2 block 62/140 (1561 nodes) done
# area 2 block 63/140 (1600 nodes) done
# area 2 block 64/140 (1541 nodes) done
# area 2 block 65/140 (1528 nodes) done
# area 2 block 66/140 (1558 nodes) done
# area 2 block 67/140 (1566 nodes) done
# area 2 block 68/140 (1539 nodes) done
# area 2 block 69/140 (1551 nodes) done
# area 2 block 70/140 (1549 nodes) done
# area 2 block 71/140 (1600 nodes) done
# area 2 block 72/140 (1600 nodes) done
# area 2 block 73/140 (1600 nodes) done
# area 2 block 74/140 (1600 nodes) done
# area 2 block 75/140 (1600 nodes) done
# area 2 block 76/140 (1600 nodes) done
# area 2 block 77/140 (1600 nodes) done
# area 2 block 78/140 (1540 nodes) done
# area 2 block 79/140 (1505 nodes) done
# area 2 block 80/140 (1555 nodes) done
# area 2 block 81/140 (1527 nodes) done
# area 2 block 82/140 (1544 nodes) done
# area 2 block 83/140 (1523 nodes) done
# area 2 block 84/140 (1550 nodes) done
# area 2 block 85/140 (1588 nodes) done
# area 2 block 86/140 (1600 nodes) done
# area 2 block 87/140 (1600 nodes) done
# area 2 block 88/140 (1565 nodes) done
# area 2 block 89/140 (1590 nodes) done
# area 2 block 90/140 (1600 nodes) done
# area 2 block 91/140 (1600 nodes) done
# area 2 block 92/140 (1585 nodes) done
# area 2 block 93/140 (1498 nodes) done
# area 2 block 94/140 (1541 nodes) done
# area 2 block 95/140 (1563 nodes) done
# area 2 block 96/140 (1554 nodes) done
# area 2 block 97/140 (1576 nodes) done
# area 2 block 98/140 (1538 nodes) done
# area 2 block 99/140 (1573 nodes) done
# area 2 block 100/140 (1545 nodes) done
# area 2 block 101/140 (1496 nodes) done
# area 2 block 102/140 (1537 nodes) done
# area 2 block 103/140 (1577 nodes) done
# area 2 block 104/140 (1519 nodes) done
# area 2 block 105/140 (1573 nodes) done
# area 2 block 106/140 (1581 nodes) done
# area 2 block 107/140 (1566 nodes) done
# area 2 block 108/140 (1538 nodes) done
# area 2 block 109/140 (1570 nodes) done
# area 2 block 110/140 (1586 nodes) done
# area 2 block 111/140 (1498 nodes) done
# area 2 block 112/140 (1548 nodes) done
# area 2 block 113/140 (1546 nodes) done
# area 2 block 114/140 (1509 nodes) done
# area 2 block 115/140 (1500 nodes) done
# area 2 block 116/140 (1546 nodes) done
# area 2 block 117/140 (1537 nodes) done
# area 2 block 118/140 (1591 nodes) done
# area 2 block 119/140 (1479 nodes) done
# area 2 block 120/140 (1496 nodes) done
# area 2 block 121/140 (1530 nodes) done
# area 2 block 122/140 (1541 nodes) done
# area 2 block 123/140 (1576 nodes) done
# area 2 block 124/140 (1600 nodes) done
# area 2 block 125/140 (1525 nodes) done
# area 2 block 126/140 (1589 nodes) done
# area 2 block 127/140 (1591 nodes) done
# area 2 block 128/140 (1530 nodes) done
# area 2 block 129/140 (1518 nodes) done
# area 2 block 130/140 (1497 nodes) done
# area 2 block 131/140 (1596 nodes) done
# area 2 block 132/140 (1581 nodes) done
# area 2 block 133/140 (1596 nodes) done
# area 2 block 134/140 (1575 nodes) done
# area 2 block 135/140 (1568 nodes) done
# area 2 block 136/140 (1600 nodes) done
# area 2 block 137/140 (1600 nodes) done
# area 2 block 138/140 (1600 nodes) done
# area 2 block 139/140 (1600 nodes) done
# area 2 block 140/140 (1520 nodes) done
#   area 3 blocks:   0%|          | 0/130 [00:00<?, ?it/s]
# area 3 block 1/130 (1562 nodes) done
# area 3 block 2/130 (1553 nodes) done
# area 3 block 3/130 (1600 nodes) done
# area 3 block 4/130 (1557 nodes) done
# area 3 block 5/130 (1453 nodes) done
# area 3 block 6/130 (1400 nodes) done
# area 3 block 7/130 (1573 nodes) done
# area 3 block 8/130 (1598 nodes) done
# area 3 block 9/130 (1600 nodes) done
# area 3 block 10/130 (1600 nodes) done
# area 3 block 11/130 (1600 nodes) done
# area 3 block 12/130 (1600 nodes) done
# area 3 block 13/130 (1600 nodes) done
# area 3 block 14/130 (1591 nodes) done
# area 3 block 15/130 (1508 nodes) done
# area 3 block 16/130 (1560 nodes) done
# area 3 block 17/130 (1574 nodes) done
# area 3 block 18/130 (1527 nodes) done
# area 3 block 19/130 (1520 nodes) done
# area 3 block 20/130 (1552 nodes) done
# area 3 block 21/130 (1527 nodes) done
# area 3 block 22/130 (1403 nodes) done
# area 3 block 23/130 (1477 nodes) done
# area 3 block 24/130 (1568 nodes) done
# area 3 block 25/130 (1600 nodes) done
# area 3 block 26/130 (1600 nodes) done
# area 3 block 27/130 (1585 nodes) done
# area 3 block 28/130 (1590 nodes) done
# area 3 block 29/130 (1587 nodes) done
# area 3 block 30/130 (1417 nodes) done
# area 3 block 31/130 (1437 nodes) done
# area 3 block 32/130 (1477 nodes) done
# area 3 block 33/130 (1484 nodes) done
# area 3 block 34/130 (1499 nodes) done
# area 3 block 35/130 (1321 nodes) done
# area 3 block 36/130 (1482 nodes) done
# area 3 block 37/130 (1385 nodes) done
# area 3 block 38/130 (1367 nodes) done
# area 3 block 39/130 (1600 nodes) done
# area 3 block 40/130 (1531 nodes) done
# area 3 block 41/130 (1554 nodes) done
# area 3 block 42/130 (1487 nodes) done
# area 3 block 43/130 (1409 nodes) done
# area 3 block 44/130 (1415 nodes) done
# area 3 block 45/130 (1363 nodes) done
# area 3 block 46/130 (1422 nodes) done
# area 3 block 47/130 (1431 nodes) done
# area 3 block 48/130 (1385 nodes) done
# area 3 block 49/130 (1401 nodes) done
# area 3 block 50/130 (1320 nodes) done
# area 3 block 51/130 (1483 nodes) done
# area 3 block 52/130 (1600 nodes) done
# area 3 block 53/130 (1562 nodes) done
# area 3 block 54/130 (1584 nodes) done
# area 3 block 55/130 (1540 nodes) done
# area 3 block 56/130 (1579 nodes) done
# area 3 block 57/130 (1332 nodes) done
# area 3 block 58/130 (1352 nodes) done
# area 3 block 59/130 (1473 nodes) done
# area 3 block 60/130 (1518 nodes) done
# area 3 block 61/130 (1511 nodes) done
# area 3 block 62/130 (1398 nodes) done
# area 3 block 63/130 (1365 nodes) done
# area 3 block 64/130 (1600 nodes) done
# area 3 block 65/130 (1600 nodes) done
# area 3 block 66/130 (1513 nodes) done
# area 3 block 67/130 (1554 nodes) done
# area 3 block 68/130 (1578 nodes) done
# area 3 block 69/130 (1501 nodes) done
# area 3 block 70/130 (1496 nodes) done
# area 3 block 71/130 (1452 nodes) done
# area 3 block 72/130 (1581 nodes) done
# area 3 block 73/130 (1596 nodes) done
# area 3 block 74/130 (1597 nodes) done
# area 3 block 75/130 (1600 nodes) done
# area 3 block 76/130 (1540 nodes) done
# area 3 block 77/130 (1600 nodes) done
# area 3 block 78/130 (1600 nodes) done
# area 3 block 79/130 (1550 nodes) done
# area 3 block 80/130 (1551 nodes) done
# area 3 block 81/130 (1529 nodes) done
# area 3 block 82/130 (1549 nodes) done
# area 3 block 83/130 (1568 nodes) done
# area 3 block 84/130 (1579 nodes) done
# area 3 block 85/130 (1585 nodes) done
# area 3 block 86/130 (1600 nodes) done
# area 3 block 87/130 (1559 nodes) done
# area 3 block 88/130 (1600 nodes) done
# area 3 block 89/130 (1600 nodes) done
# area 3 block 90/130 (1600 nodes) done
# area 3 block 91/130 (1600 nodes) done
# area 3 block 92/130 (1542 nodes) done
# area 3 block 93/130 (1562 nodes) done
# area 3 block 94/130 (1575 nodes) done
# area 3 block 95/130 (1595 nodes) done
# area 3 block 96/130 (1510 nodes) done
# area 3 block 97/130 (1559 nodes) done
# area 3 block 98/130 (1571 nodes) done
# area 3 block 99/130 (1476 nodes) done
# area 3 block 100/130 (1491 nodes) done
# area 3 block 101/130 (1451 nodes) done
# area 3 block 102/130 (1600 nodes) done
# area 3 block 103/130 (1600 nodes) done
# area 3 block 104/130 (1600 nodes) done
# area 3 block 105/130 (1586 nodes) done
# area 3 block 106/130 (1579 nodes) done
# area 3 block 107/130 (1559 nodes) done
# area 3 block 108/130 (1570 nodes) done
# area 3 block 109/130 (1584 nodes) done
# area 3 block 110/130 (1521 nodes) done
# area 3 block 111/130 (1272 nodes) done
# area 3 block 112/130 (1336 nodes) done
# area 3 block 113/130 (1387 nodes) done
# area 3 block 114/130 (1569 nodes) done
# area 3 block 115/130 (1590 nodes) done
# area 3 block 116/130 (1525 nodes) done
# area 3 block 117/130 (1600 nodes) done
# area 3 block 118/130 (1532 nodes) done
# area 3 block 119/130 (1579 nodes) done
# area 3 block 120/130 (1561 nodes) done
# area 3 block 121/130 (1371 nodes) done
# area 3 block 122/130 (1370 nodes) done
# area 3 block 123/130 (1318 nodes) done
# area 3 block 124/130 (1406 nodes) done
# area 3 block 125/130 (1402 nodes) done
# area 3 block 126/130 (1294 nodes) done
# area 3 block 127/130 (1508 nodes) done
# area 3 block 128/130 (1543 nodes) done
# area 3 block 129/130 (1272 nodes) done
# area 3 block 130/130 (1304 nodes) done
#   area 4 blocks:   0%|          | 0/143 [00:00<?, ?it/s]
# area 4 block 1/143 (1584 nodes) done
# area 4 block 2/143 (1600 nodes) done
# area 4 block 3/143 (1463 nodes) done
# area 4 block 4/143 (1427 nodes) done
# area 4 block 5/143 (1476 nodes) done
# area 4 block 6/143 (1491 nodes) done
# area 4 block 7/143 (1370 nodes) done
# area 4 block 8/143 (1409 nodes) done
# area 4 block 9/143 (1501 nodes) done
# area 4 block 10/143 (1600 nodes) done
# area 4 block 11/143 (1600 nodes) done
# area 4 block 12/143 (1590 nodes) done
# area 4 block 13/143 (1600 nodes) done
# area 4 block 14/143 (1364 nodes) done
# area 4 block 15/143 (1401 nodes) done
# area 4 block 16/143 (1559 nodes) done
# area 4 block 17/143 (1379 nodes) done
# area 4 block 18/143 (1430 nodes) done
# area 4 block 19/143 (1456 nodes) done
# area 4 block 20/143 (1504 nodes) done
# area 4 block 21/143 (1586 nodes) done
# area 4 block 22/143 (1569 nodes) done
# area 4 block 23/143 (1600 nodes) done
# area 4 block 24/143 (1600 nodes) done
# area 4 block 25/143 (1586 nodes) done
# area 4 block 26/143 (1600 nodes) done
# area 4 block 27/143 (1514 nodes) done
# area 4 block 28/143 (1465 nodes) done
# area 4 block 29/143 (1349 nodes) done
# area 4 block 30/143 (1502 nodes) done
# area 4 block 31/143 (1436 nodes) done
# area 4 block 32/143 (1200 nodes) done
# area 4 block 33/143 (1562 nodes) done
# area 4 block 34/143 (1600 nodes) done
# area 4 block 35/143 (1570 nodes) done
# area 4 block 36/143 (1501 nodes) done
# area 4 block 37/143 (1585 nodes) done
# area 4 block 38/143 (1503 nodes) done
# area 4 block 39/143 (1431 nodes) done
# area 4 block 40/143 (1378 nodes) done
# area 4 block 41/143 (1460 nodes) done
# area 4 block 42/143 (1531 nodes) done
# area 4 block 43/143 (1451 nodes) done
# area 4 block 44/143 (1591 nodes) done
# area 4 block 45/143 (1600 nodes) done
# area 4 block 46/143 (1512 nodes) done
# area 4 block 47/143 (1425 nodes) done
# area 4 block 48/143 (1450 nodes) done
# area 4 block 49/143 (1359 nodes) done
# area 4 block 50/143 (1463 nodes) done
# area 4 block 51/143 (1364 nodes) done
# area 4 block 52/143 (1435 nodes) done
# area 4 block 53/143 (1438 nodes) done
# area 4 block 54/143 (1503 nodes) done
# area 4 block 55/143 (1483 nodes) done
# area 4 block 56/143 (1600 nodes) done
# area 4 block 57/143 (1517 nodes) done
# area 4 block 58/143 (1437 nodes) done
# area 4 block 59/143 (1398 nodes) done
# area 4 block 60/143 (1408 nodes) done
# area 4 block 61/143 (1420 nodes) done
# area 4 block 62/143 (1461 nodes) done
# area 4 block 63/143 (1585 nodes) done
# area 4 block 64/143 (1481 nodes) done
# area 4 block 65/143 (1592 nodes) done
# area 4 block 66/143 (1486 nodes) done
# area 4 block 67/143 (1600 nodes) done
# area 4 block 68/143 (1487 nodes) done
# area 4 block 69/143 (1416 nodes) done
# area 4 block 70/143 (1474 nodes) done
# area 4 block 71/143 (1553 nodes) done
# area 4 block 72/143 (1600 nodes) done
# area 4 block 73/143 (1600 nodes) done
# area 4 block 74/143 (1600 nodes) done
# area 4 block 75/143 (1441 nodes) done
# area 4 block 76/143 (1600 nodes) done
# area 4 block 77/143 (1600 nodes) done
# area 4 block 78/143 (1589 nodes) done
# area 4 block 79/143 (1456 nodes) done
# area 4 block 80/143 (1500 nodes) done
# area 4 block 81/143 (1549 nodes) done
# area 4 block 82/143 (1586 nodes) done
# area 4 block 83/143 (1600 nodes) done
# area 4 block 84/143 (1600 nodes) done
# area 4 block 85/143 (1600 nodes) done
# area 4 block 86/143 (1600 nodes) done
# area 4 block 87/143 (1600 nodes) done
# area 4 block 88/143 (1600 nodes) done
# area 4 block 89/143 (1579 nodes) done
# area 4 block 90/143 (1471 nodes) done
# area 4 block 91/143 (1516 nodes) done
# area 4 block 92/143 (1600 nodes) done
# area 4 block 93/143 (1588 nodes) done
# area 4 block 94/143 (1600 nodes) done
# area 4 block 95/143 (1600 nodes) done
# area 4 block 96/143 (1600 nodes) done
# area 4 block 97/143 (1600 nodes) done
# area 4 block 98/143 (1600 nodes) done
# area 4 block 99/143 (1600 nodes) done
# area 4 block 100/143 (1598 nodes) done
# area 4 block 101/143 (1509 nodes) done
# area 4 block 102/143 (1429 nodes) done
# area 4 block 103/143 (1600 nodes) done
# area 4 block 104/143 (1600 nodes) done
# area 4 block 105/143 (1600 nodes) done
# area 4 block 106/143 (1600 nodes) done
# area 4 block 107/143 (1600 nodes) done
# area 4 block 108/143 (1600 nodes) done
# area 4 block 109/143 (1600 nodes) done
# area 4 block 110/143 (1458 nodes) done
# area 4 block 111/143 (1571 nodes) done
# area 4 block 112/143 (1465 nodes) done
# area 4 block 113/143 (1500 nodes) done
# area 4 block 114/143 (1600 nodes) done
# area 4 block 115/143 (1600 nodes) done
# area 4 block 116/143 (1584 nodes) done
# area 4 block 117/143 (1590 nodes) done
# area 4 block 118/143 (1600 nodes) done
# area 4 block 119/143 (1600 nodes) done
# area 4 block 120/143 (1560 nodes) done
# area 4 block 121/143 (1427 nodes) done
# area 4 block 122/143 (1497 nodes) done
# area 4 block 123/143 (1534 nodes) done
# area 4 block 124/143 (1557 nodes) done
# area 4 block 125/143 (1557 nodes) done
# area 4 block 126/143 (1600 nodes) done
# area 4 block 127/143 (1600 nodes) done
# area 4 block 128/143 (1600 nodes) done
# area 4 block 129/143 (1600 nodes) done
# area 4 block 130/143 (1600 nodes) done
# area 4 block 131/143 (1551 nodes) done
# area 4 block 132/143 (1339 nodes) done
# area 4 block 133/143 (1516 nodes) done
# area 4 block 134/143 (1593 nodes) done
# area 4 block 135/143 (1545 nodes) done
# area 4 block 136/143 (1543 nodes) done
# area 4 block 137/143 (1593 nodes) done
# area 4 block 138/143 (1582 nodes) done
# area 4 block 139/143 (1600 nodes) done
# area 4 block 140/143 (1507 nodes) done
# area 4 block 141/143 (1451 nodes) done
# area 4 block 142/143 (1474 nodes) done
# area 4 block 143/143 (1524 nodes) done
#   area 5 blocks:   0%|          | 0/154 [00:00<?, ?it/s]
# area 5 block 1/154 (1560 nodes) done
# area 5 block 2/154 (1501 nodes) done
# area 5 block 3/154 (1277 nodes) done
# area 5 block 4/154 (1554 nodes) done
# area 5 block 5/154 (1512 nodes) done
# area 5 block 6/154 (1560 nodes) done
# area 5 block 7/154 (1560 nodes) done
# area 5 block 8/154 (1555 nodes) done
# area 5 block 9/154 (1540 nodes) done
# area 5 block 10/154 (1558 nodes) done
# area 5 block 11/154 (1533 nodes) done
# area 5 block 12/154 (1535 nodes) done
# area 5 block 13/154 (1543 nodes) done
# area 5 block 14/154 (1539 nodes) done
# area 5 block 15/154 (1596 nodes) done
# area 5 block 16/154 (1552 nodes) done
# area 5 block 17/154 (1390 nodes) done
# area 5 block 18/154 (1597 nodes) done
# area 5 block 19/154 (1568 nodes) done
# area 5 block 20/154 (1520 nodes) done
# area 5 block 21/154 (1583 nodes) done
# area 5 block 22/154 (1565 nodes) done
# area 5 block 23/154 (1573 nodes) done
# area 5 block 24/154 (1550 nodes) done
# area 5 block 25/154 (1562 nodes) done
# area 5 block 26/154 (1571 nodes) done
# area 5 block 27/154 (1600 nodes) done
# area 5 block 28/154 (1597 nodes) done
# area 5 block 29/154 (1534 nodes) done
# area 5 block 30/154 (1516 nodes) done
# area 5 block 31/154 (1567 nodes) done
# area 5 block 32/154 (1600 nodes) done
# area 5 block 33/154 (1600 nodes) done
# area 5 block 34/154 (1600 nodes) done
# area 5 block 35/154 (1246 nodes) done
# area 5 block 36/154 (1579 nodes) done
# area 5 block 37/154 (1563 nodes) done
# area 5 block 38/154 (1566 nodes) done
# area 5 block 39/154 (1562 nodes) done
# area 5 block 40/154 (1583 nodes) done
# area 5 block 41/154 (1583 nodes) done
# area 5 block 42/154 (1600 nodes) done
# area 5 block 43/154 (1523 nodes) done
# area 5 block 44/154 (1544 nodes) done
# area 5 block 45/154 (1596 nodes) done
# area 5 block 46/154 (1600 nodes) done
# area 5 block 47/154 (1600 nodes) done
# area 5 block 48/154 (1600 nodes) done
# area 5 block 49/154 (1600 nodes) done
# area 5 block 50/154 (1600 nodes) done
# area 5 block 51/154 (1588 nodes) done
# area 5 block 52/154 (1558 nodes) done
# area 5 block 53/154 (1586 nodes) done
# area 5 block 54/154 (1569 nodes) done
# area 5 block 55/154 (1588 nodes) done
# area 5 block 56/154 (1564 nodes) done
# area 5 block 57/154 (1540 nodes) done
# area 5 block 58/154 (1525 nodes) done
# area 5 block 59/154 (1593 nodes) done
# area 5 block 60/154 (1600 nodes) done
# area 5 block 61/154 (1600 nodes) done
# area 5 block 62/154 (1600 nodes) done
# area 5 block 63/154 (1600 nodes) done
# area 5 block 64/154 (1600 nodes) done
# area 5 block 65/154 (1575 nodes) done
# area 5 block 66/154 (1549 nodes) done
# area 5 block 67/154 (1542 nodes) done
# area 5 block 68/154 (1592 nodes) done
# area 5 block 69/154 (1600 nodes) done
# area 5 block 70/154 (1600 nodes) done
# area 5 block 71/154 (1536 nodes) done
# area 5 block 72/154 (1547 nodes) done
# area 5 block 73/154 (1600 nodes) done
# area 5 block 74/154 (1600 nodes) done
# area 5 block 75/154 (1600 nodes) done
# area 5 block 76/154 (1600 nodes) done
# area 5 block 77/154 (1600 nodes) done
# area 5 block 78/154 (1565 nodes) done
# area 5 block 79/154 (1569 nodes) done
# area 5 block 80/154 (1562 nodes) done
# area 5 block 81/154 (1540 nodes) done
# area 5 block 82/154 (1573 nodes) done
# area 5 block 83/154 (1595 nodes) done
# area 5 block 84/154 (1597 nodes) done
# area 5 block 85/154 (1536 nodes) done
# area 5 block 86/154 (1600 nodes) done
# area 5 block 87/154 (1593 nodes) done
# area 5 block 88/154 (1600 nodes) done
# area 5 block 89/154 (1600 nodes) done
# area 5 block 90/154 (1600 nodes) done
# area 5 block 91/154 (1600 nodes) done
# area 5 block 92/154 (1559 nodes) done
# area 5 block 93/154 (1580 nodes) done
# area 5 block 94/154 (1568 nodes) done
# area 5 block 95/154 (1583 nodes) done
# area 5 block 96/154 (1600 nodes) done
# area 5 block 97/154 (1600 nodes) done
# area 5 block 98/154 (1585 nodes) done
# area 5 block 99/154 (1581 nodes) done
# area 5 block 100/154 (1544 nodes) done
# area 5 block 101/154 (1591 nodes) done
# area 5 block 102/154 (1589 nodes) done
# area 5 block 103/154 (1586 nodes) done
# area 5 block 104/154 (1600 nodes) done
# area 5 block 105/154 (1600 nodes) done
# area 5 block 106/154 (1554 nodes) done
# area 5 block 107/154 (1530 nodes) done
# area 5 block 108/154 (1570 nodes) done
# area 5 block 109/154 (1558 nodes) done
# area 5 block 110/154 (1600 nodes) done
# area 5 block 111/154 (1600 nodes) done
# area 5 block 112/154 (1595 nodes) done
# area 5 block 113/154 (1536 nodes) done
# area 5 block 114/154 (1558 nodes) done
# area 5 block 115/154 (1574 nodes) done
# area 5 block 116/154 (1600 nodes) done
# area 5 block 117/154 (1590 nodes) done
# area 5 block 118/154 (1600 nodes) done
# area 5 block 119/154 (1600 nodes) done
# area 5 block 120/154 (1574 nodes) done
# area 5 block 121/154 (1548 nodes) done
# area 5 block 122/154 (1577 nodes) done
# area 5 block 123/154 (1555 nodes) done
# area 5 block 124/154 (1591 nodes) done
# area 5 block 125/154 (1553 nodes) done
# area 5 block 126/154 (1516 nodes) done
# area 5 block 127/154 (1543 nodes) done
# area 5 block 128/154 (1579 nodes) done
# area 5 block 129/154 (1579 nodes) done
# area 5 block 130/154 (1600 nodes) done
# area 5 block 131/154 (1600 nodes) done
# area 5 block 132/154 (1600 nodes) done
# area 5 block 133/154 (1600 nodes) done
# area 5 block 134/154 (1597 nodes) done
# area 5 block 135/154 (1577 nodes) done
# area 5 block 136/154 (1600 nodes) done
# area 5 block 137/154 (1594 nodes) done
# area 5 block 138/154 (1589 nodes) done
# area 5 block 139/154 (1581 nodes) done
# area 5 block 140/154 (1556 nodes) done
# area 5 block 141/154 (1568 nodes) done
# area 5 block 142/154 (1580 nodes) done
# area 5 block 143/154 (1566 nodes) done
# area 5 block 144/154 (1574 nodes) done
# area 5 block 145/154 (1591 nodes) done
# area 5 block 146/154 (1600 nodes) done
# area 5 block 147/154 (1600 nodes) done
# area 5 block 148/154 (1600 nodes) done
# area 5 block 149/154 (1600 nodes) done
# area 5 block 150/154 (1600 nodes) done
# area 5 block 151/154 (1600 nodes) done
# area 5 block 152/154 (1513 nodes) done
# area 5 block 153/154 (1600 nodes) done
# area 5 block 154/154 (1600 nodes) done
#   area 6 blocks:   0%|          | 0/144 [00:00<?, ?it/s]
# area 6 block 1/144 (1600 nodes) done
# area 6 block 2/144 (1600 nodes) done
# area 6 block 3/144 (1600 nodes) done
# area 6 block 4/144 (1600 nodes) done
# area 6 block 5/144 (1527 nodes) done
# area 6 block 6/144 (1584 nodes) done
# area 6 block 7/144 (1592 nodes) done
# area 6 block 8/144 (1511 nodes) done
# area 6 block 9/144 (1574 nodes) done
# area 6 block 10/144 (1575 nodes) done
# area 6 block 11/144 (1528 nodes) done
# area 6 block 12/144 (1462 nodes) done
# area 6 block 13/144 (1600 nodes) done
# area 6 block 14/144 (1425 nodes) done
# area 6 block 15/144 (1600 nodes) done
# area 6 block 16/144 (1600 nodes) done
# area 6 block 17/144 (1584 nodes) done
# area 6 block 18/144 (1461 nodes) done
# area 6 block 19/144 (1570 nodes) done
# area 6 block 20/144 (1463 nodes) done
# area 6 block 21/144 (1483 nodes) done
# area 6 block 22/144 (1445 nodes) done
# area 6 block 23/144 (1474 nodes) done
# area 6 block 24/144 (1428 nodes) done
# area 6 block 25/144 (1600 nodes) done
# area 6 block 26/144 (1600 nodes) done
# area 6 block 27/144 (1600 nodes) done
# area 6 block 28/144 (1277 nodes) done
# area 6 block 29/144 (1007 nodes) done
# area 6 block 30/144 (1475 nodes) done
# area 6 block 31/144 (1592 nodes) done
# area 6 block 32/144 (1452 nodes) done
# area 6 block 33/144 (1469 nodes) done
# area 6 block 34/144 (1424 nodes) done
# area 6 block 35/144 (1482 nodes) done
# area 6 block 36/144 (1423 nodes) done
# area 6 block 37/144 (1600 nodes) done
# area 6 block 38/144 (1600 nodes) done
# area 6 block 39/144 (1600 nodes) done
# area 6 block 40/144 (1529 nodes) done
# area 6 block 41/144 (1308 nodes) done
# area 6 block 42/144 (1558 nodes) done
# area 6 block 43/144 (1298 nodes) done
# area 6 block 44/144 (1467 nodes) done
# area 6 block 45/144 (1469 nodes) done
# area 6 block 46/144 (1428 nodes) done
# area 6 block 47/144 (1390 nodes) done
# area 6 block 48/144 (1471 nodes) done
# area 6 block 49/144 (1600 nodes) done
# area 6 block 50/144 (1600 nodes) done
# area 6 block 51/144 (1558 nodes) done
# area 6 block 52/144 (1584 nodes) done
# area 6 block 53/144 (1335 nodes) done
# area 6 block 54/144 (1217 nodes) done
# area 6 block 55/144 (1488 nodes) done
# area 6 block 56/144 (1568 nodes) done
# area 6 block 57/144 (1440 nodes) done
# area 6 block 58/144 (1440 nodes) done
# area 6 block 59/144 (1409 nodes) done
# area 6 block 60/144 (1443 nodes) done
# area 6 block 61/144 (1600 nodes) done
# area 6 block 62/144 (1600 nodes) done
# area 6 block 63/144 (1598 nodes) done
# area 6 block 64/144 (1579 nodes) done
# area 6 block 65/144 (1600 nodes) done
# area 6 block 66/144 (1600 nodes) done
# area 6 block 67/144 (1596 nodes) done
# area 6 block 68/144 (1556 nodes) done
# area 6 block 69/144 (1454 nodes) done
# area 6 block 70/144 (1385 nodes) done
# area 6 block 71/144 (1243 nodes) done
# area 6 block 72/144 (1424 nodes) done
# area 6 block 73/144 (1600 nodes) done
# area 6 block 74/144 (1600 nodes) done
# area 6 block 75/144 (1577 nodes) done
# area 6 block 76/144 (1526 nodes) done
# area 6 block 77/144 (1600 nodes) done
# area 6 block 78/144 (1595 nodes) done
# area 6 block 79/144 (1600 nodes) done
# area 6 block 80/144 (1590 nodes) done
# area 6 block 81/144 (1491 nodes) done
# area 6 block 82/144 (1396 nodes) done
# area 6 block 83/144 (1311 nodes) done
# area 6 block 84/144 (1334 nodes) done
# area 6 block 85/144 (1600 nodes) done
# area 6 block 86/144 (1581 nodes) done
# area 6 block 87/144 (1558 nodes) done
# area 6 block 88/144 (1557 nodes) done
# area 6 block 89/144 (1471 nodes) done
# area 6 block 90/144 (1497 nodes) done
# area 6 block 91/144 (1504 nodes) done
# area 6 block 92/144 (1583 nodes) done
# area 6 block 93/144 (1591 nodes) done
# area 6 block 94/144 (1521 nodes) done
# area 6 block 95/144 (1385 nodes) done
# area 6 block 96/144 (1450 nodes) done
# area 6 block 97/144 (1479 nodes) done
# area 6 block 98/144 (1458 nodes) done
# area 6 block 99/144 (1477 nodes) done
# area 6 block 100/144 (1487 nodes) done
# area 6 block 101/144 (1427 nodes) done
# area 6 block 102/144 (1428 nodes) done
# area 6 block 103/144 (1450 nodes) done
# area 6 block 104/144 (1469 nodes) done
# area 6 block 105/144 (1551 nodes) done
# area 6 block 106/144 (1481 nodes) done
# area 6 block 107/144 (1420 nodes) done
# area 6 block 108/144 (1512 nodes) done
# area 6 block 109/144 (1408 nodes) done
# area 6 block 110/144 (1451 nodes) done
# area 6 block 111/144 (1453 nodes) done
# area 6 block 112/144 (1467 nodes) done
# area 6 block 113/144 (1404 nodes) done
# area 6 block 114/144 (1449 nodes) done
# area 6 block 115/144 (1371 nodes) done
# area 6 block 116/144 (1438 nodes) done
# area 6 block 117/144 (1405 nodes) done
# area 6 block 118/144 (1381 nodes) done
# area 6 block 119/144 (1541 nodes) done
# area 6 block 120/144 (1554 nodes) done
# area 6 block 121/144 (1443 nodes) done
# area 6 block 122/144 (1407 nodes) done
# area 6 block 123/144 (1470 nodes) done
# area 6 block 124/144 (1440 nodes) done
# area 6 block 125/144 (1382 nodes) done
# area 6 block 126/144 (1319 nodes) done
# area 6 block 127/144 (1370 nodes) done
# area 6 block 128/144 (1359 nodes) done
# area 6 block 129/144 (1359 nodes) done
# area 6 block 130/144 (1329 nodes) done
# area 6 block 131/144 (1105 nodes) done
# area 6 block 132/144 (1376 nodes) done
# area 6 block 133/144 (1424 nodes) done
# area 6 block 134/144 (1477 nodes) done
# area 6 block 135/144 (1509 nodes) done
# area 6 block 136/144 (1425 nodes) done
# area 6 block 137/144 (1407 nodes) done
# area 6 block 138/144 (1432 nodes) done
# area 6 block 139/144 (1435 nodes) done
# area 6 block 140/144 (1472 nodes) done
# area 6 block 141/144 (1333 nodes) done
# area 6 block 142/144 (1216 nodes) done
# area 6 block 143/144 (1206 nodes) done
# area 6 block 144/144 (1364 nodes) done
#   area 7 blocks:   0%|          | 0/169 [00:00<?, ?it/s]
# area 7 block 1/169 (1560 nodes) done
# area 7 block 2/169 (1560 nodes) done
# area 7 block 3/169 (1560 nodes) done
# area 7 block 4/169 (1560 nodes) done
# area 7 block 5/169 (1560 nodes) done
# area 7 block 6/169 (1560 nodes) done
# area 7 block 7/169 (1560 nodes) done
# area 7 block 8/169 (1560 nodes) done
# area 7 block 9/169 (1560 nodes) done
# area 7 block 10/169 (1456 nodes) done
# area 7 block 11/169 (1395 nodes) done
# area 7 block 12/169 (1392 nodes) done
# area 7 block 13/169 (1370 nodes) done
# area 7 block 14/169 (1600 nodes) done
# area 7 block 15/169 (1600 nodes) done
# area 7 block 16/169 (1600 nodes) done
# area 7 block 17/169 (1600 nodes) done
# area 7 block 18/169 (1600 nodes) done
# area 7 block 19/169 (1600 nodes) done
# area 7 block 20/169 (1600 nodes) done
# area 7 block 21/169 (1600 nodes) done
# area 7 block 22/169 (1600 nodes) done
# area 7 block 23/169 (1587 nodes) done
# area 7 block 24/169 (1600 nodes) done
# area 7 block 25/169 (1600 nodes) done
# area 7 block 26/169 (1413 nodes) done
# area 7 block 27/169 (1451 nodes) done
# area 7 block 28/169 (1562 nodes) done
# area 7 block 29/169 (1600 nodes) done
# area 7 block 30/169 (1600 nodes) done
# area 7 block 31/169 (1600 nodes) done
# area 7 block 32/169 (1555 nodes) done
# area 7 block 33/169 (1588 nodes) done
# area 7 block 34/169 (1600 nodes) done
# area 7 block 35/169 (1600 nodes) done
# area 7 block 36/169 (1600 nodes) done
# area 7 block 37/169 (1600 nodes) done
# area 7 block 38/169 (1600 nodes) done
# area 7 block 39/169 (1600 nodes) done
# area 7 block 40/169 (1422 nodes) done
# area 7 block 41/169 (1600 nodes) done
# area 7 block 42/169 (1600 nodes) done
# area 7 block 43/169 (1600 nodes) done
# area 7 block 44/169 (1600 nodes) done
# area 7 block 45/169 (1600 nodes) done
# area 7 block 46/169 (1600 nodes) done
# area 7 block 47/169 (1539 nodes) done
# area 7 block 48/169 (1413 nodes) done
# area 7 block 49/169 (1434 nodes) done
# area 7 block 50/169 (1600 nodes) done
# area 7 block 51/169 (1600 nodes) done
# area 7 block 52/169 (1600 nodes) done
# area 7 block 53/169 (1600 nodes) done
# area 7 block 54/169 (1600 nodes) done
# area 7 block 55/169 (1600 nodes) done
# area 7 block 56/169 (1600 nodes) done
# area 7 block 57/169 (1600 nodes) done
# area 7 block 58/169 (1600 nodes) done
# area 7 block 59/169 (1600 nodes) done
# area 7 block 60/169 (1496 nodes) done
# area 7 block 61/169 (1365 nodes) done
# area 7 block 62/169 (1393 nodes) done
# area 7 block 63/169 (1600 nodes) done
# area 7 block 64/169 (1600 nodes) done
# area 7 block 65/169 (1600 nodes) done
# area 7 block 66/169 (1600 nodes) done
# area 7 block 67/169 (1600 nodes) done
# area 7 block 68/169 (1600 nodes) done
# area 7 block 69/169 (1600 nodes) done
# area 7 block 70/169 (1600 nodes) done
# area 7 block 71/169 (1600 nodes) done
# area 7 block 72/169 (1600 nodes) done
# area 7 block 73/169 (1480 nodes) done
# area 7 block 74/169 (1450 nodes) done
# area 7 block 75/169 (1428 nodes) done
# area 7 block 76/169 (1499 nodes) done
# area 7 block 77/169 (1600 nodes) done
# area 7 block 78/169 (1600 nodes) done
# area 7 block 79/169 (1600 nodes) done
# area 7 block 80/169 (1600 nodes) done
# area 7 block 81/169 (1547 nodes) done
# area 7 block 82/169 (1550 nodes) done
# area 7 block 83/169 (1600 nodes) done
# area 7 block 84/169 (1600 nodes) done
# area 7 block 85/169 (1600 nodes) done
# area 7 block 86/169 (1399 nodes) done
# area 7 block 87/169 (1539 nodes) done
# area 7 block 88/169 (1547 nodes) done
# area 7 block 89/169 (1402 nodes) done
# area 7 block 90/169 (1600 nodes) done
# area 7 block 91/169 (1600 nodes) done
# area 7 block 92/169 (1600 nodes) done
# area 7 block 93/169 (1600 nodes) done
# area 7 block 94/169 (1381 nodes) done
# area 7 block 95/169 (1491 nodes) done
# area 7 block 96/169 (1600 nodes) done
# area 7 block 97/169 (1600 nodes) done
# area 7 block 98/169 (1534 nodes) done
# area 7 block 99/169 (1474 nodes) done
# area 7 block 100/169 (1470 nodes) done
# area 7 block 101/169 (1600 nodes) done
# area 7 block 102/169 (1510 nodes) done
# area 7 block 103/169 (1600 nodes) done
# area 7 block 104/169 (1600 nodes) done
# area 7 block 105/169 (1600 nodes) done
# area 7 block 106/169 (1600 nodes) done
# area 7 block 107/169 (1600 nodes) done
# area 7 block 108/169 (1600 nodes) done
# area 7 block 109/169 (1600 nodes) done
# area 7 block 110/169 (1600 nodes) done
# area 7 block 111/169 (1544 nodes) done
# area 7 block 112/169 (1519 nodes) done
# area 7 block 113/169 (1447 nodes) done
# area 7 block 114/169 (1600 nodes) done
# area 7 block 115/169 (1588 nodes) done
# area 7 block 116/169 (1600 nodes) done
# area 7 block 117/169 (1563 nodes) done
# area 7 block 118/169 (1537 nodes) done
# area 7 block 119/169 (1566 nodes) done
# area 7 block 120/169 (1600 nodes) done
# area 7 block 121/169 (1584 nodes) done
# area 7 block 122/169 (1591 nodes) done
# area 7 block 123/169 (1559 nodes) done
# area 7 block 124/169 (1596 nodes) done
# area 7 block 125/169 (1600 nodes) done
# area 7 block 126/169 (1598 nodes) done
# area 7 block 127/169 (1600 nodes) done
# area 7 block 128/169 (1600 nodes) done
# area 7 block 129/169 (1600 nodes) done
# area 7 block 130/169 (1600 nodes) done
# area 7 block 131/169 (1361 nodes) done
# area 7 block 132/169 (1578 nodes) done
# area 7 block 133/169 (1587 nodes) done
# area 7 block 134/169 (1562 nodes) done
# area 7 block 135/169 (1472 nodes) done
# area 7 block 136/169 (1544 nodes) done
# area 7 block 137/169 (1551 nodes) done
# area 7 block 138/169 (1493 nodes) done
# area 7 block 139/169 (1546 nodes) done
# area 7 block 140/169 (1522 nodes) done
# area 7 block 141/169 (1600 nodes) done
# area 7 block 142/169 (1600 nodes) done
# area 7 block 143/169 (1501 nodes) done
# area 7 block 144/169 (1512 nodes) done
# area 7 block 145/169 (1543 nodes) done
# area 7 block 146/169 (1597 nodes) done
# area 7 block 147/169 (1535 nodes) done
# area 7 block 148/169 (1513 nodes) done
# area 7 block 149/169 (1487 nodes) done
# area 7 block 150/169 (1486 nodes) done
# area 7 block 151/169 (1488 nodes) done
# area 7 block 152/169 (1431 nodes) done
# area 7 block 153/169 (1349 nodes) done
# area 7 block 154/169 (1600 nodes) done
# area 7 block 155/169 (1600 nodes) done
# area 7 block 156/169 (1422 nodes) done
# area 7 block 157/169 (1581 nodes) done
# area 7 block 158/169 (1566 nodes) done
# area 7 block 159/169 (1539 nodes) done
# area 7 block 160/169 (1421 nodes) done
# area 7 block 161/169 (1455 nodes) done
# area 7 block 162/169 (1538 nodes) done
# area 7 block 163/169 (1287 nodes) done
# area 7 block 164/169 (1507 nodes) done
# area 7 block 165/169 (1430 nodes) done
# area 7 block 166/169 (1322 nodes) done
# area 7 block 167/169 (1529 nodes) done
# area 7 block 168/169 (1521 nodes) done
# area 7 block 169/169 (1470 nodes) done
#   area 8 blocks:   0%|          | 0/126 [00:00<?, ?it/s]
# area 8 block 1/126 (1379 nodes) done
# area 8 block 2/126 (1323 nodes) done
# area 8 block 3/126 (1336 nodes) done
# area 8 block 4/126 (1524 nodes) done
# area 8 block 5/126 (1134 nodes) done
# area 8 block 6/126 (1392 nodes) done
# area 8 block 7/126 (1556 nodes) done
# area 8 block 8/126 (1560 nodes) done
# area 8 block 9/126 (1560 nodes) done
# area 8 block 10/126 (1476 nodes) done
# area 8 block 11/126 (1360 nodes) done
# area 8 block 12/126 (1392 nodes) done
# area 8 block 13/126 (1454 nodes) done
# area 8 block 14/126 (1494 nodes) done
# area 8 block 15/126 (1342 nodes) done
# area 8 block 16/126 (1357 nodes) done
# area 8 block 17/126 (1402 nodes) done
# area 8 block 18/126 (1550 nodes) done
# area 8 block 19/126 (1520 nodes) done
# area 8 block 20/126 (1532 nodes) done
# area 8 block 21/126 (1507 nodes) done
# area 8 block 22/126 (1474 nodes) done
# area 8 block 23/126 (1496 nodes) done
# area 8 block 24/126 (1571 nodes) done
# area 8 block 25/126 (1464 nodes) done
# area 8 block 26/126 (1404 nodes) done
# area 8 block 27/126 (1408 nodes) done
# area 8 block 28/126 (1415 nodes) done
# area 8 block 29/126 (1307 nodes) done
# area 8 block 30/126 (1368 nodes) done
# area 8 block 31/126 (1356 nodes) done
# area 8 block 32/126 (1364 nodes) done
# area 8 block 33/126 (1399 nodes) done
# area 8 block 34/126 (1447 nodes) done
# area 8 block 35/126 (1382 nodes) done
# area 8 block 36/126 (1323 nodes) done
# area 8 block 37/126 (1233 nodes) done
# area 8 block 38/126 (1413 nodes) done
# area 8 block 39/126 (1098 nodes) done
# area 8 block 40/126 (1314 nodes) done
# area 8 block 41/126 (1487 nodes) done
# area 8 block 42/126 (1533 nodes) done
# area 8 block 43/126 (1354 nodes) done
# area 8 block 44/126 (1292 nodes) done
# area 8 block 45/126 (1321 nodes) done
# area 8 block 46/126 (1285 nodes) done
# area 8 block 47/126 (1299 nodes) done
# area 8 block 48/126 (1309 nodes) done
# area 8 block 49/126 (1323 nodes) done
# area 8 block 50/126 (1354 nodes) done
# area 8 block 51/126 (1308 nodes) done
# area 8 block 52/126 (1359 nodes) done
# area 8 block 53/126 (1311 nodes) done
# area 8 block 54/126 (1292 nodes) done
# area 8 block 55/126 (1338 nodes) done
# area 8 block 56/126 (1519 nodes) done
# area 8 block 57/126 (1351 nodes) done
# area 8 block 58/126 (1320 nodes) done
# area 8 block 59/126 (1365 nodes) done
# area 8 block 60/126 (1289 nodes) done
# area 8 block 61/126 (1304 nodes) done
# area 8 block 62/126 (1304 nodes) done
# area 8 block 63/126 (1313 nodes) done
# area 8 block 64/126 (1359 nodes) done
# area 8 block 65/126 (1354 nodes) done
# area 8 block 66/126 (1229 nodes) done
# area 8 block 67/126 (1314 nodes) done
# area 8 block 68/126 (1281 nodes) done
# area 8 block 69/126 (1387 nodes) done
# area 8 block 70/126 (1581 nodes) done
# area 8 block 71/126 (1362 nodes) done
# area 8 block 72/126 (1365 nodes) done
# area 8 block 73/126 (1266 nodes) done
# area 8 block 74/126 (1315 nodes) done
# area 8 block 75/126 (1374 nodes) done
# area 8 block 76/126 (1402 nodes) done
# area 8 block 77/126 (1352 nodes) done
# area 8 block 78/126 (1437 nodes) done
# area 8 block 79/126 (1483 nodes) done
# area 8 block 80/126 (1457 nodes) done
# area 8 block 81/126 (1475 nodes) done
# area 8 block 82/126 (1488 nodes) done
# area 8 block 83/126 (1546 nodes) done
# area 8 block 84/126 (1549 nodes) done
# area 8 block 85/126 (1395 nodes) done
# area 8 block 86/126 (1216 nodes) done
# area 8 block 87/126 (1352 nodes) done
# area 8 block 88/126 (1342 nodes) done
# area 8 block 89/126 (1365 nodes) done
# area 8 block 90/126 (1116 nodes) done
# area 8 block 91/126 (1321 nodes) done
# area 8 block 92/126 (1205 nodes) done
# area 8 block 93/126 (1226 nodes) done
# area 8 block 94/126 (1348 nodes) done
# area 8 block 95/126 (1547 nodes) done
# area 8 block 96/126 (1434 nodes) done
# area 8 block 97/126 (1274 nodes) done
# area 8 block 98/126 (1337 nodes) done
# area 8 block 99/126 (1427 nodes) done
# area 8 block 100/126 (1425 nodes) done
# area 8 block 101/126 (1355 nodes) done
# area 8 block 102/126 (1390 nodes) done
# area 8 block 103/126 (1345 nodes) done
# area 8 block 104/126 (1320 nodes) done
# area 8 block 105/126 (1309 nodes) done
# area 8 block 106/126 (1290 nodes) done
# area 8 block 107/126 (1282 nodes) done
# area 8 block 108/126 (1315 nodes) done
# area 8 block 109/126 (1577 nodes) done
# area 8 block 110/126 (1390 nodes) done
# area 8 block 111/126 (1356 nodes) done
# area 8 block 112/126 (1458 nodes) done
# area 8 block 113/126 (1484 nodes) done
# area 8 block 114/126 (1525 nodes) done
# area 8 block 115/126 (1479 nodes) done
# area 8 block 116/126 (1368 nodes) done
# area 8 block 117/126 (1410 nodes) done
# area 8 block 118/126 (1405 nodes) done
# area 8 block 119/126 (1390 nodes) done
# area 8 block 120/126 (1365 nodes) done
# area 8 block 121/126 (1456 nodes) done
# area 8 block 122/126 (1476 nodes) done
# area 8 block 123/126 (1355 nodes) done
# area 8 block 124/126 (1338 nodes) done
# area 8 block 125/126 (1346 nodes) done
# area 8 block 126/126 (1453 nodes) done
#   area 9 blocks:   0%|          | 0/120 [00:00<?, ?it/s]
# area 9 block 1/120 (1554 nodes) done
# area 9 block 2/120 (1414 nodes) done
# area 9 block 3/120 (1411 nodes) done
# area 9 block 4/120 (1385 nodes) done
# area 9 block 5/120 (1102 nodes) done
# area 9 block 6/120 (1212 nodes) done
# area 9 block 7/120 (1265 nodes) done
# area 9 block 8/120 (1199 nodes) done
# area 9 block 9/120 (1381 nodes) done
# area 9 block 10/120 (1363 nodes) done
# area 9 block 11/120 (1427 nodes) done
# area 9 block 12/120 (1498 nodes) done
# area 9 block 13/120 (1530 nodes) done
# area 9 block 14/120 (1360 nodes) done
# area 9 block 15/120 (1368 nodes) done
# area 9 block 16/120 (1323 nodes) done
# area 9 block 17/120 (1291 nodes) done
# area 9 block 18/120 (1169 nodes) done
# area 9 block 19/120 (777 nodes) done
# area 9 block 20/120 (1090 nodes) done
# area 9 block 21/120 (1472 nodes) done
# area 9 block 22/120 (1450 nodes) done
# area 9 block 23/120 (1592 nodes) done
# area 9 block 24/120 (1600 nodes) done
# area 9 block 25/120 (1509 nodes) done
# area 9 block 26/120 (1550 nodes) done
# area 9 block 27/120 (1394 nodes) done
# area 9 block 28/120 (1372 nodes) done
# area 9 block 29/120 (1286 nodes) done
# area 9 block 30/120 (1232 nodes) done
# area 9 block 31/120 (1104 nodes) done
# area 9 block 32/120 (1384 nodes) done
# area 9 block 33/120 (1589 nodes) done
# area 9 block 34/120 (1523 nodes) done
# area 9 block 35/120 (1506 nodes) done
# area 9 block 36/120 (1600 nodes) done
# area 9 block 37/120 (1412 nodes) done
# area 9 block 38/120 (1499 nodes) done
# area 9 block 39/120 (1381 nodes) done
# area 9 block 40/120 (1297 nodes) done
# area 9 block 41/120 (1425 nodes) done
# area 9 block 42/120 (1407 nodes) done
# area 9 block 43/120 (1580 nodes) done
# area 9 block 44/120 (1365 nodes) done
# area 9 block 45/120 (1590 nodes) done
# area 9 block 46/120 (1579 nodes) done
# area 9 block 47/120 (1484 nodes) done
# area 9 block 48/120 (1457 nodes) done
# area 9 block 49/120 (1438 nodes) done
# area 9 block 50/120 (1426 nodes) done
# area 9 block 51/120 (1539 nodes) done
# area 9 block 52/120 (1567 nodes) done
# area 9 block 53/120 (1600 nodes) done
# area 9 block 54/120 (1600 nodes) done
# area 9 block 55/120 (1596 nodes) done
# area 9 block 56/120 (1500 nodes) done
# area 9 block 57/120 (1384 nodes) done
# area 9 block 58/120 (1470 nodes) done
# area 9 block 59/120 (1328 nodes) done
# area 9 block 60/120 (1311 nodes) done
# area 9 block 61/120 (1454 nodes) done
# area 9 block 62/120 (1504 nodes) done
# area 9 block 63/120 (1600 nodes) done
# area 9 block 64/120 (1600 nodes) done
# area 9 block 65/120 (1555 nodes) done
# area 9 block 66/120 (1551 nodes) done
# area 9 block 67/120 (1489 nodes) done
# area 9 block 68/120 (1542 nodes) done
# area 9 block 69/120 (1393 nodes) done
# area 9 block 70/120 (1469 nodes) done
# area 9 block 71/120 (1358 nodes) done
# area 9 block 72/120 (1414 nodes) done
# area 9 block 73/120 (1600 nodes) done
# area 9 block 74/120 (1600 nodes) done
# area 9 block 75/120 (1555 nodes) done
# area 9 block 76/120 (1600 nodes) done
# area 9 block 77/120 (1540 nodes) done
# area 9 block 78/120 (1461 nodes) done
# area 9 block 79/120 (1318 nodes) done
# area 9 block 80/120 (1525 nodes) done
# area 9 block 81/120 (1529 nodes) done
# area 9 block 82/120 (1344 nodes) done
# area 9 block 83/120 (1494 nodes) done
# area 9 block 84/120 (1386 nodes) done
# area 9 block 85/120 (1317 nodes) done
# area 9 block 86/120 (1543 nodes) done
# area 9 block 87/120 (1558 nodes) done
# area 9 block 88/120 (1537 nodes) done
# area 9 block 89/120 (1472 nodes) done
# area 9 block 90/120 (1503 nodes) done
# area 9 block 91/120 (1416 nodes) done
# area 9 block 92/120 (1398 nodes) done
# area 9 block 93/120 (1556 nodes) done
# area 9 block 94/120 (1484 nodes) done
# area 9 block 95/120 (1504 nodes) done
# area 9 block 96/120 (1502 nodes) done
# area 9 block 97/120 (1465 nodes) done
# area 9 block 98/120 (1435 nodes) done
# area 9 block 99/120 (1349 nodes) done
# area 9 block 100/120 (1302 nodes) done
# area 9 block 101/120 (1393 nodes) done
# area 9 block 102/120 (1451 nodes) done
# area 9 block 103/120 (1379 nodes) done
# area 9 block 104/120 (1449 nodes) done
# area 9 block 105/120 (1471 nodes) done
# area 9 block 106/120 (1560 nodes) done
# area 9 block 107/120 (1551 nodes) done
# area 9 block 108/120 (1515 nodes) done
# area 9 block 109/120 (1440 nodes) done
# area 9 block 110/120 (1416 nodes) done
# area 9 block 111/120 (1321 nodes) done
# area 9 block 112/120 (1320 nodes) done
# area 9 block 113/120 (1321 nodes) done
# area 9 block 114/120 (1428 nodes) done
# area 9 block 115/120 (1203 nodes) done
# area 9 block 116/120 (1348 nodes) done
# area 9 block 117/120 (1600 nodes) done
# area 9 block 118/120 (1491 nodes) done
# area 9 block 119/120 (1567 nodes) done
# area 9 block 120/120 (1589 nodes) done
#   area 10 blocks:   0%|          | 0/120 [00:00<?, ?it/s]
# area 10 block 1/120 (1522 nodes) done
# area 10 block 2/120 (1558 nodes) done
# area 10 block 3/120 (1549 nodes) done
# area 10 block 4/120 (1495 nodes) done
# area 10 block 5/120 (1543 nodes) done
# area 10 block 6/120 (1546 nodes) done
# area 10 block 7/120 (1556 nodes) done
# area 10 block 8/120 (1527 nodes) done
# area 10 block 9/120 (1564 nodes) done
# area 10 block 10/120 (1541 nodes) done
# area 10 block 11/120 (1568 nodes) done
# area 10 block 12/120 (1574 nodes) done
# area 10 block 13/120 (1572 nodes) done
# area 10 block 14/120 (1600 nodes) done
# area 10 block 15/120 (1560 nodes) done
# area 10 block 16/120 (1556 nodes) done
# area 10 block 17/120 (1555 nodes) done
# area 10 block 18/120 (1558 nodes) done
# area 10 block 19/120 (1561 nodes) done
# area 10 block 20/120 (1581 nodes) done
# area 10 block 21/120 (1551 nodes) done
# area 10 block 22/120 (1531 nodes) done
# area 10 block 23/120 (1586 nodes) done
# area 10 block 24/120 (1600 nodes) done
# area 10 block 25/120 (1600 nodes) done
# area 10 block 26/120 (1596 nodes) done
# area 10 block 27/120 (1581 nodes) done
# area 10 block 28/120 (1549 nodes) done
# area 10 block 29/120 (1585 nodes) done
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File ~/OneDrive/Assignments/Semester-7/reinforcement-learning/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1621, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1617             raise TypeError(
#    1618                 f"Mismatch between array dtype ('{str(X.dtype)}') and "
#    1619                 f"format specifier ('{format}')"
#    1620             ) from e
# -> 1621         fh.write(v)
#    1623 if len(footer) > 0:
#
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# OSError: [Errno 28] No space left on device
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# Cell In[14], line 26
#      22         for j in range(NumFreq):
#      23             os.makedirs(f'FreqDepth{chayufenzi}/{AreaIndex+1}/{Frequency[j]}', exist_ok=True)
#      24             chayuzhi = chayufenzi / math.log(Frequency[j], 10)
#      25             adj = compute_adj_vectorized(suoyin, SFDepth, chayuzhi, dcor)
# ---> 26             np.savetxt(f'FreqDepth{chayufenzi}/{AreaIndex+1}/{Frequency[j]}/{m+1}_{n+1}.txt', adj, fmt='%d')
#      27
#      28         tqdm.write(f"area {AreaIndex+1} block {BlockIndex+1}/{n_blocks} ({Num_Node} nodes) done")
#
# File ~/OneDrive/Assignments/Semester-7/reinforcement-learning/.venv/lib/python3.12/site-packages/numpy/lib/_npyio_impl.py:1628, in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1626 finally:
#    1627     if own_fh:
# -> 1628         fh.close()
#
# OSError: [Errno 28] No space left on device

# %%
class GATConv(nn.Module):
    def __init__(self, in_channels, out_channels, bias=True):
        super().__init__()
        self.weight_w = nn.Parameter(torch.FloatTensor(in_channels, out_channels))
        self.weight_a = nn.Parameter(torch.FloatTensor(out_channels * 2, 1))
        self.bias = nn.Parameter(torch.FloatTensor(out_channels, 1)) if bias else None
        self.leakyrelu = nn.LeakyReLU()
        nn.init.xavier_uniform_(self.weight_w)
        nn.init.xavier_uniform_(self.weight_a)
        if self.bias is not None:
            nn.init.zeros_(self.bias)

    def forward(self, x, edge_index):
        wh = torch.mm(x, self.weight_w)
        e = torch.mm(wh, self.weight_a[:self.weight_a.shape[0]//2]) + \
            torch.matmul(wh, self.weight_a[self.weight_a.shape[0]//2:]).T
        e = self.leakyrelu(e)
        attention = torch.where(edge_index > 0, e, -1e9 * torch.ones_like(e))
        attention = F.softmax(attention, dim=1)
        output = torch.mm(attention, wh)
        return output + self.bias.flatten() if self.bias is not None else output

class GAT(nn.Module):
    def __init__(self, num_node_features, num_classes):
        super().__init__()
        self.conv1 = GATConv(num_node_features, 80)
        self.conv2 = GATConv(80, 320)
        self.conv3 = GATConv(320, num_classes)

    def forward(self, x, edge_index, out_edge_index):
        x = F.relu(self.conv1(x, edge_index))
        x = F.dropout(x, p=0.5, training=self.training)
        x = F.relu(self.conv2(x, out_edge_index))
        x = F.dropout(x, p=0.5, training=self.training)
        return self.conv3(x, out_edge_index)

# %%
BlockX = BlockY = 40
axis = np.loadtxt(f'New_axis{BlockX}.txt', dtype=int)
Carry_Freq = np.array(Freq)
Train_Freq_Index = np.array([0,1,2,3])
Num_All_Freq = 5
Num_train_Freq = Num_Out_Freq = Num_In_Freq = 1
Input_Freq_Index = Out_Freq_Index = 0
Num_Node_Max = 1600
StationsPosition = np.loadtxt('stations_position.txt', dtype=int)

percent  = 0.05
masklv   = 1 - percent
method   = 1     # 0 Obsadj, 1 depadj, 2 Aroundadj, 3 TransmitterAdj
toupiao  = 0
device   = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
epochs   = 3 if QUICK_TEST else 250
lr       = 0.0005

area_range = range(1) if QUICK_TEST else range(10)

for AreaIndex in tqdm(area_range, desc="GAT: areas"):
    Num_All_Block   = int(axis[AreaIndex,0]*axis[AreaIndex,1]/BlockY/BlockX)
    Num_All_Block_X = int(axis[AreaIndex,1]/BlockX)
    if QUICK_TEST:
        Num_All_Block = min(Num_All_Block, QUICK_TEST_BLOCKS)
    Train_Percent = 0.5
    Num_Train_Block = int(Num_All_Block * Train_Percent)
    Num_Test_Block  = Num_All_Block - Num_Train_Block

    np.random.seed(0)
    Block_Index = np.arange(Num_All_Block)
    np.random.shuffle(Block_Index)

    N_Node = np.ones(Num_All_Block, dtype=int)
    for i in Block_Index:
        m, n = divmod(i, Num_All_Block_X)
        N_Node[i] = len(np.loadtxt(f'NodeFeatureStrength{BlockX}/{AreaIndex+1}/{Carry_Freq[0]}/{m+1}_{n+1}.txt', dtype=float))

    All_Mask = np.ones((Num_All_Block, Num_All_Freq, Num_Node_Max), dtype=int)
    np.random.seed(0)
    for i in Block_Index:
        train_mask0 = np.ones((Num_All_Freq, N_Node[i]), dtype=int)
        train_mask0[:, 0:int(N_Node[i]*masklv)] = 0
        for j in range(Num_All_Freq):
            np.random.shuffle(train_mask0[j, :])
        All_Mask[i, :, 0:N_Node[i]] = train_mask0

    Num_Axis_Feature = 2
    Num_Feature = Num_Axis_Feature + Num_In_Freq + Num_Out_Freq + Num_In_Freq
    All_Feature = np.ones((Num_All_Block, Num_Node_Max, Num_Feature, Num_All_Freq))

    for i in tqdm(Block_Index, desc=f"  area {AreaIndex+1}: features", leave=False):
        m, n = divmod(i, Num_All_Block_X)
        for k in range(Num_All_Freq):
            axis_data = np.loadtxt(f'NodeFeatureAxis{BlockX}/{AreaIndex+1}/{Carry_Freq[0]}/{m+1}_{n+1}.txt', dtype=float).T
            All_Feature[i, 0:N_Node[i], 0:Num_Axis_Feature, k] = axis_data
            All_Feature[i, 0:N_Node[i], 0, k] = (All_Feature[i, 0:N_Node[i], 0, k] + 40*m) / (int(axis[AreaIndex,0]/BlockY)) / 40
            All_Feature[i, 0:N_Node[i], 1, k] = (All_Feature[i, 0:N_Node[i], 1, k] + 40*n) / Num_All_Block_X / 40
            for j in range(Num_In_Freq):
                strength = np.loadtxt(f'NodeFeatureStrength{BlockX}/{AreaIndex+1}/{Carry_Freq[j]}/{m+1}_{n+1}.txt', dtype=float)
                All_Feature[i, 0:N_Node[i], Num_Axis_Feature+Num_In_Freq+Num_Out_Freq+j, k] = (All_Mask[i,k,0:N_Node[i]] * strength) / (-100)

    All_Y = np.ones((Num_All_Block, Num_Node_Max, Num_All_Freq))
    for i in Block_Index:
        m, n = divmod(i, Num_All_Block_X)
        for j in range(Num_All_Freq):
            All_Y[i, 0:N_Node[i], j] = np.loadtxt(f'NodeFeatureStrength{BlockX}/{AreaIndex+1}/{Carry_Freq[j]}/{m+1}_{n+1}.txt', dtype=float) / (-100)

    # FIX 1: int8 instead of default int64 -- this array was OOM-ing at 12+ GiB per area.
    All_Adj = np.ones((Num_All_Freq, Num_All_Block, Num_Node_Max, Num_Node_Max), dtype=np.int8)
    for j in tqdm(range(Num_All_Freq), desc=f"  area {AreaIndex+1}: adjacency", leave=False):
        for i in Block_Index:
            m, n = divmod(i, Num_All_Block_X)
            if method == 0:
                All_Adj[j,i,0:N_Node[i],0:N_Node[i]] = np.loadtxt(f'ObstructionAdj_6_40/{AreaIndex+1}/{m+1}_{n+1}.txt', dtype=int)
            elif method == 1:
                # FIX 2: this must match the folder Depth_Adj_Generate.py actually writes
                # (FreqDepth{chayufenzi} = FreqDepth0.1 by default), not "FreqDepth0.1_3".
                All_Adj[j,i,0:N_Node[i],0:N_Node[i]] = np.loadtxt(f'FreqDepth0.1/{AreaIndex+1}/{Carry_Freq[j]}/{m+1}_{n+1}.txt', dtype=int)
            elif method == 2:
                All_Adj[j,i,0:N_Node[i],0:N_Node[i]] = np.loadtxt(f'AroundAdj40/{AreaIndex+1}/{m+1}_{n+1}.txt', dtype=int)
            elif method == 3:
                All_Adj[j,i,0:N_Node[i],0:N_Node[i]] = np.loadtxt(f'TransmitterAdj40/{AreaIndex+1}/{m+1}_{n+1}.txt', dtype=int)
            adj0 = np.eye(N_Node[i], dtype=np.int8)
            All_Adj[j,i,0:N_Node[i],0:N_Node[i]] = adj0 + All_Adj[j,i,0:N_Node[i],0:N_Node[i]]

    model = GAT(Num_Feature, Num_Out_Freq).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    loss_function = nn.MSELoss()

    loss0 = np.ones(epochs)
    acc0  = np.ones(epochs)
    epoch_bar = tqdm(range(epochs), desc=f"  area {AreaIndex+1}: training")

    for epoch in epoch_bar:
        model.train()
        for i in Block_Index[0:Num_Train_Block]:
            for k in range(Num_train_Freq):
                Feature = All_Feature[i, 0:N_Node[i], :, k].copy()
                Feature[:, Num_Axis_Feature] = Carry_Freq[Train_Freq_Index[k]] / 5750
                Feature[:, Num_Axis_Feature+Num_In_Freq] = Carry_Freq[Out_Freq_Index] / 5750
                Adj = torch.FloatTensor(All_Adj[Train_Freq_Index[k], i, 0:N_Node[i], 0:N_Node[i]])
                Feature = torch.FloatTensor(Feature).requires_grad_(True)
                OutAdj = torch.FloatTensor(All_Adj[0, i, 0:N_Node[i], 0:N_Node[i]])
                optimizer.zero_grad()
                Pred = model(Feature.to(device), Adj.to(device), OutAdj.to(device))
                if Carry_Freq[Train_Freq_Index[k]] == Carry_Freq[Out_Freq_Index]:
                    mask = torch.tensor(All_Mask[i, Out_Freq_Index, 0:N_Node[i]]).bool()
                    Mask_Pred = Pred[mask]
                    Mask_Real = All_Y[i, 0:N_Node[i], Out_Freq_Index][mask]
                else:
                    Mask_Pred = Pred
                    Mask_Real = All_Y[i, 0:N_Node[i], Out_Freq_Index]
                Mask_Real = torch.FloatTensor(Mask_Real)
                loss = loss_function(Mask_Pred[:, 0].to(device), Mask_Real.to(device))
                loss.backward()
                optimizer.step()
        loss0[epoch] = loss.item()

        model.eval()
        if epoch % 10 == 0 or epoch == epochs - 1:
            mse = 0
            for i in Block_Index[Num_Train_Block:Num_All_Block]:
                Feature = All_Feature[i, 0:N_Node[i], :, Input_Freq_Index].copy()
                Feature[:, Num_Axis_Feature] = Carry_Freq[Input_Freq_Index] / 5750
                Feature[:, Num_Axis_Feature+Num_In_Freq] = Carry_Freq[Out_Freq_Index] / 5750
                Adj = torch.FloatTensor(All_Adj[Input_Freq_Index, i, 0:N_Node[i], 0:N_Node[i]])
                Feature = torch.FloatTensor(Feature).requires_grad_(True)
                OutAdj = torch.FloatTensor(All_Adj[Out_Freq_Index, i, 0:N_Node[i], 0:N_Node[i]])
                Pred = model(Feature.to(device), Adj.to(device), OutAdj.to(device))
                mask = torch.tensor(1 - All_Mask[i, Out_Freq_Index, 0:N_Node[i]]).bool()
                Mask_Pred = Pred[mask, 0]
                Mask_Real = All_Y[i, 0:N_Node[i], Out_Freq_Index][mask]
                mse = np.sqrt(mse*mse + mean_squared_error(Mask_Pred.cpu().detach().numpy(), Mask_Real))
            acc0[epoch] = 100 * mse / np.sqrt(Num_Test_Block)
            epoch_bar.set_postfix(loss=f"{loss0[epoch]:.4f}", val_rmse=f"{acc0[epoch]:.4f}")

    tqdm.write(f"area {AreaIndex+1}: final loss={loss0[-1]:.4f}, final val RMSE={acc0[epochs-1]:.4f}")

    # Reconstruct the full map for this area for visualization
    model.eval()
    Num_All_Block_Y = int(axis[AreaIndex,0]/BlockY)
    zongtu = np.ones((Num_All_Block_X*40, Num_All_Block_Y*40), dtype=float)
    for i in Block_Index:
        m, n = divmod(i, Num_All_Block_X)
        Feature = All_Feature[i, 0:N_Node[i], :, Input_Freq_Index].copy()
        Feature[:, Num_Axis_Feature] = Carry_Freq[Input_Freq_Index] / 5750
        Feature[:, Num_Axis_Feature+Num_In_Freq] = Carry_Freq[Out_Freq_Index] / 5750
        Adj = torch.FloatTensor(All_Adj[Input_Freq_Index, i, 0:N_Node[i], 0:N_Node[i]])
        Feature = torch.FloatTensor(Feature).requires_grad_(True)
        OutAdj = torch.FloatTensor(All_Adj[Out_Freq_Index, i, 0:N_Node[i], 0:N_Node[i]])
        Pred = model(Feature.to(device), Adj.to(device), OutAdj.to(device))
        axistest = np.loadtxt(f'NodeFeatureAxis{BlockX}/{AreaIndex+1}/{Carry_Freq[0]}/{m+1}_{n+1}.txt', dtype=int).T
        u = axistest[0:N_Node[i], 0] + 40*m
        v = axistest[0:N_Node[i], 1] + 40*n
        zongtu[v, u] = Pred[:, 0].cpu().detach().numpy() * (-100)
    zongtu[np.where(zongtu == 1)] = 0

    plt.figure(figsize=(6,5))
    plt.imshow(zongtu.T, cmap='jet', norm=plt.Normalize(vmin=-100, vmax=-10))
    plt.colorbar()
    plt.title(f"Area {AreaIndex+1} reconstructed radio map")
    plt.show()
